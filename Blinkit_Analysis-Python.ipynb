# %% [markdown]
# # **DATA ANALYSIS PYTHON PROJECT-BLINKIT ANALYSIS**

# %% [markdown]
# ## **Import Libraryes**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Import Sample Data**

# %%
pf = pd.read_excel(r"D:\DATA_ANALYST.tutorial\POWER_BI_PROJECT\2-Blinkit Sales_data_project_BI\BlinkIT Grocery Data.xlsx")

# %% [markdown]
# ### **Frist 10 Row of Data**

# %%
pf.head(11)
# Out:
#    Item Fat Content Item Identifier              Item Type  \
# 0           Regular           FDX32  Fruits and Vegetables
# 1           Low Fat           NCB42     Health and Hygiene
# 2           Regular           FDR28           Frozen Foods
# 3           Regular           FDL50                 Canned
# 4           Low Fat           DRI25            Soft Drinks
# 5           low fat           FDS52           Frozen Foods
# 6           Low Fat           NCU05     Health and Hygiene
# 7           Low Fat           NCD30              Household
# 8           Low Fat           FDW20  Fruits and Vegetables
# 9           Low Fat           FDX25                 Canned
# 10               LF           FDX21            Snack Foods
#
#     Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                        2012            OUT049               Tier 1
# 1                        2022            OUT018               Tier 3
# ...

# %% [markdown]
# ### **Last 10 Row of Data**

# %%
pf.tail(10)
# Out:
#      Item Fat Content Item Identifier              Item Type  \
# 8513          Regular           DRY23            Soft Drinks
# 8514          low fat           FDA11           Baking Goods
# 8515          low fat           FDK38                 Canned
# 8516          low fat           FDO38                 Canned
# 8517          low fat           FDG32  Fruits and Vegetables
# 8518          low fat           NCT53     Health and Hygiene
# 8519          low fat           FDN09            Snack Foods
# 8520          low fat           DRE13            Soft Drinks
# 8521              reg           FDT50                  Dairy
# 8522              reg           FDM58            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 8513                       2018            OUT027               Tier 3
# 8514                       2018            OUT027               Tier 3
# 8515                       2018            OUT027               Tier 3
# ...

# %% [markdown]
# ### **Size of Data**

# %%
print("Size of Data",pf.shape)
# Out:
# Size of Data (8523, 12)

# %% [markdown]
# ### **Field info**

# %%
pf.columns
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %% [markdown]
# ### **Dta Types**

# %%
pf.dtypes
# Out:
# Item Fat Content              object
# Item Identifier               object
# Item Type                     object
# Outlet Establishment Year      int64
# Outlet Identifier             object
# Outlet Location Type          object
# Outlet Size                   object
# Outlet Type                   object
# Item Visibility              float64
# Item Weight                  float64
# Sales                        float64
# Rating                       float64
# dtype: object

# %% [markdown]
# ### **Data Cleaning**

# %%
print(pf["Item Fat Content"].unique())
# Out:
# ['Regular' 'Low Fat' 'low fat' 'LF' 'reg']

# %%
pf["Item Fat Content"]=pf["Item Fat Content"].replace({'reg':'Regular','low fat':'Low Fat','LF':'Low Fat'})

# %%
print(pf["Item Fat Content"].unique())
# Out:
# ['Regular' 'Low Fat']

# %% [markdown]
# # **Business Requrement**

# %% [markdown]
# ### **KPI's Requrement**

# %%
#Total Sales:
Total_Sales=pf['Sales'].sum()
#Avg Sales:
AVG_Sales=pf["Sales"].mean()
#Number of Iteam sold:
Num_of_Iteam_sold=pf["Sales"].count()
#Aerage Rating:
AVG_Rating=pf["Rating"].mean()
#Disply:
print(f"Total Sales: ${Total_Sales: ,.0f}")
print(f"Average Sales: ${AVG_Sales: ,.1f}")
print(f"Number of Iteam Sold: {Num_of_Iteam_sold:,.0f}")
print(f"Average Rating: {AVG_Rating: ,.1f}")
# Out:
# Total Sales: $ 1,201,681
# Average Sales: $ 141.0
# Number of Iteam Sold: 8,523
# Average Rating:  4.0

# %% [markdown]
# ### **Sales By Fat Content**

# %%
Sales_by_fat=pf.groupby("Item Fat Content") ["Sales"].sum()
plt.pie(Sales_by_fat,labels=Sales_by_fat.index,
       autopct='% .0f%%',
       startangle=90)
plt.title("Item Fat Content",color='red')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### **Sales By Iteam Type**

# %%
sales_by_type=pf.groupby("Item Type") ["Sales"].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
bars=plt.bar(sales_by_type.index,sales_by_type.values)

plt.xticks(rotation=-90)
plt.xlabel("Item type")
plt.ylabel("Total Sales")
plt.title("Total Sales By Item Type")

for bar in bars:
    plt.text(bar.get_x()+bar.get_width() /2,bar.get_height(),f"{bar.get_height():,.0f}",ha='center',va='bottom',fontsize=8)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Fat Content by outlet for Total Sales**

# %%
pf['Item Fat Content'] = pf['Item Fat Content'].str.lower().str.strip()
pf['Item Fat Content'] = pf['Item Fat Content'].replace({
    'lf': 'low fat',
    'reg': 'regular'
})

grouped = pf.groupby(['Outlet Location Type', 'Item Fat Content'])['Sales'].sum().unstack()
grouped = grouped[['regular', 'low fat']]

ax = grouped.plot(kind='bar', figsize=(10, 5), title="Outlet Tier by Item Fat Content")
ax.set_xlabel("Outlet Location Type")
ax.set_ylabel("Total Sales")
ax.legend(title='Item Fat Content')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Total Sales by outlet establishment**

# %%
sales_by_year=pf.groupby("Outlet Establishment Year") ["Sales"].sum().sort_index()

plt.figure(figsize=(9,5))
plt.plot(sales_by_year.index,sales_by_year.values,marker='o',linestyle='-')


plt.xlabel("outlet establishment year")
plt.ylabel("Total Sales")
plt.title("outlet establishment")

for x,y in zip(sales_by_year.index,sales_by_year.values):
   plt.text(x,y,f'{y:,.0f}',ha='center',va='bottom',fontsize=8)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Sales by Outlet Size**

# %%
sales_by_outlet=pf.groupby('Outlet Size') ['Sales'].sum()

plt.pie(sales_by_outlet,labels=sales_by_outlet.index,autopct='%1.1f%%',startangle=90)
plt.title("Outlet Size")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Sales by Outlet Location**

# %%
Sales_By_Location=pf.groupby("Outlet Location Type") ["Sales"].sum().reset_index()
Sales_By_Location=Sales_By_Location.sort_values("Sales",ascending=False)

plt.figure(figsize=(8,4))
ax=sns.barplot(x="Sales",y="Outlet Location Type",data=Sales_By_Location)

plt.title("Total Sales by outlet Location Type")
plt.xlabel("Total Sales")
plt.ylabel("Outlet Location Type")
plt.tight_layout()
plt.show()
